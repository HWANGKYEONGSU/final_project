# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings(action="ignore")

import matplotlib.font_manager as fm
font_name = fm.FontProperties(fname="C:/Windows/Fonts/malgun.ttf").get_name()
plt.rc("font", family=font_name)

import matplotlib as mpl
mpl.rcParams["axes.unicode_minus"] = False


import urllib.request as req
from urllib.request import urlopen
from urllib.error import HTTPError,URLError
import urllib.parse
from bs4 import BeautifulSoup
import requests

from sklearn import linear_model
from scipy import stats
import statsmodels
import statsmodels.api as sm
import statsmodels.formula.api as smf
import statsmodels.stats.api as sms
from statsmodels.compat import lzip

import seaborn as sns
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

plt.rcParams['figure.figsize'] = (7, 7)
plt.style.use('ggplot')
from patsy import dmatrix, dmatrices
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
df1 = pd.read_csv("data/1-1000.csv", index_col = 0)    
df2 = pd.read_csv("data/1001-2000.csv", index_col = 0)    
df3 = pd.read_csv("data/2000~3000.csv", index_col = 0)    
df4 = pd.read_csv("data/3000~4000.csv", index_col = 0)    
df5 = pd.read_csv("data/4000~5000.csv", index_col = 0)    
df6 = pd.read_csv("data/5000~6000.csv", index_col = 0)    
df7 = pd.read_csv("data/6001~6460.csv", index_col = 0)    
df8 =  pd.read_csv("data/5000-6000.csv", index_col = 0)

# %%
result1 = pd.concat([df1,df2,df3,df4,df5,df8,df7],ignore_index=True)

# %%
result1[:]
# Out:
#                                    상품명    현재 펀딩 금액  펀딩 퍼센트       목표금액   후원자 수
# 0        기독교 대천사부터 본디에이의 천사까지, <천사소개록>  84,418,200     959  8,800,000  2,729명
# 1         게으른 완벽주의자들을 위한 플래너 <데일리 처방전>  16,690,000     525  3,173,279    592명
# 2          고전에서 발굴한 해몽 기록, <꿈보다 해몽> 도감  12,837,000     641  2,000,000    613명
# 3          기다리고 기다렸다! 창작자를 위한 테크웨어 브러쉬  21,411,000    1427  1,500,000    438명
# 4            왕이 사랑한 보석같은 궁중디저트를 선물합니다.   8,911,000     891  1,000,000    126명
# ...                                ...         ...     ...        ...     ...
# 6415  올 여름 무더위를 날려버릴 99년생 보컬들의 구구콘 라이브   8,157,000     326  2,500,000    208명
# 6416      건국대학교 중앙연극동아리 건대극장 '베니스의 상인'   1,305,000     326    400,000     68명
# 6417         1년 12달, 12가지 개성을 담은 드레스퍼퓸   1,630,500     326    500,000     40명
# 6418         지켜낸 그들에게 건네는 위로, <연극> 그 날   3,261,000     326  1,000,000    115명
# 6419      초보집사의 동거생활 <가난한 집사, 냥님을 모시다>     581,000     326      배송 완료     22명
#
# [6420 rows x 5 columns]

# %%
result1.to_csv("data/notjinhaeng-1-6460.csv", encoding = "utf-8")

# %%
df8
# Out:
#                                  상품명    현재 펀딩 금액  펀딩 퍼센트       목표금액 후원자 수
# 0    [설 선물] 달콤한 벌집꿀로, 달달한 사랑을 전해보세요.   4,246,800     424      배송 완료   61명
# 1                심쿵~♥ 빼빼로데이 골든에그 마들렌   1,274,000     424      배송 완료   35명
# 2                미니피규어&토미카 장식장 '루돌프'   1,911,000     424    450,000   16명
# 3             "私は黙らない(우리는 입다물지 않는다)"   2,122,500     424    500,000  251명
# 4     제주의 자연을 담은 싱글&블랜딩 TEA와 휴대용 인퓨저   2,122,000     424    500,000   64명
# ..                               ...         ...     ...        ...   ...
# 995      [앵콜]사군자 한국 트럼프 카드 & 핸드폰 케이스  10,595,000     353      배송 완료  368명
# 996  펫 드라이 자켓 「드라이 한방」으로 뽀송하게 털 말리기!  10,595,000     353  3,000,000  254명
# 997       아기 꿀벌이 전해준 봄의 향기 '허니 아카시아'   3,531,600     353      배송 완료   97명
# 998    일상과 낭만을 기록하는 다이어리키트, <로맨틱레코드>   1,765,722     353      배송 완료   52명
# 999                    독립출판을 위한 인디자인   2,472,000     353      배송 완료  164명
#
# [1000 rows x 5 columns]
